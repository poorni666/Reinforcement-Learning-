# %%
# Cell 1: Imports and Setup
import os
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import Counter
import torch.nn.functional as F

# %%
# Import from modules
from wordle_core import vocabulary, wordle_feedback
from wordle_env import WordleEnv
from wordle_agent import WordleA2CNet, masked_softmax
from config import *
from evaluate import evaluate_agent_with_games
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# %%
# Load Vocabulary
vocab, solutions, VOCAB_SIZE, WORD_TO_IDX = vocabulary(VOCAB_PATH, SOLUTIONS_PATH)
# Out:
# VOCABULARY:
#    Solutions: 2315 words (targets only)
#    Allowed guesses: 12972 words (full action space)
#    Training vocabulary: 12972 words

# %%
# Initialize Environment and Agent
train_env = WordleEnv(vocab, solutions, WORD_TO_IDX, training_mode=True)
eval_env = WordleEnv(vocab, solutions, WORD_TO_IDX, training_mode=False)

agent = WordleA2CNet(INPUT_DIM, VOCAB_SIZE).to(device)
optimizer = optim.Adam(agent.parameters(), lr=LR, weight_decay=1e-5)


print(f"   Parameters: {sum(p.numel() for p in agent.parameters()):,}")
print(f"   Device: {device}")
# Out:
#    Parameters: 2,373,933
#    Device: cpu

# %%
# Training Setup
win_rates = []
avg_guesses_list = []
entropy_history = []
best_win_rate = 0.0

# %%
# Training Loop
for ep in range(NUM_EPISODES):
    obs, mask = train_env.reset()
    log_probs, values, rewards, entropies = [], [], [], []
    done = False

    while not done:
        obs_t = obs.unsqueeze(0).to(device)
        mask_t = mask.unsqueeze(0).to(device)

        logits, value = agent(obs_t)
        probs, current_temp = masked_softmax(logits, mask_t, ep, NUM_EPISODES)

        dist = torch.distributions.Categorical(probs)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        entropy = dist.entropy()

        obs, reward, done, mask = train_env.step(action.item())

        log_probs.append(log_prob)
        values.append(value)
        rewards.append(reward)
        entropies.append(entropy)

    # A2C update
    R = 0
    returns_batch = []
    for r in reversed(rewards):
        R = r + GAMMA * R
        returns_batch.insert(0, R)

    returns_batch = torch.tensor(returns_batch, dtype=torch.float32).to(device)
    values = torch.cat(values)
    log_probs = torch.cat(log_probs)
    advantages = returns_batch - values

    actor_loss = -(log_probs * advantages.detach()).mean()
    critic_loss = F.mse_loss(values, returns_batch)
    entropy_loss = -ENTROPY_COEF * torch.stack(entropies).mean() if entropies else 0
    loss = actor_loss + critic_loss + entropy_loss

    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(agent.parameters(), max_norm=1.0)
    optimizer.step()

    if entropies:
        entropy_history.append(torch.stack(entropies).mean().item())

    # Evaluation
    if (ep + 1) % EVAL_EVERY == 0:
        win_rate, avg_guesses = evaluate_agent_with_games(ep + 1, num_display_games=2)
        win_rates.append(win_rate)
        avg_guesses_list.append(avg_guesses)

        print(f"   Training: Temp={current_temp:.2f}")

        if win_rate > best_win_rate:
            best_win_rate = win_rate
            torch.save({
                'model_state_dict': agent.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'win_rate': win_rate,
                'episode': ep
            }, SAVE_PATH)
            print(f" Saved best model (Win Rate: {win_rate:.1%})")
        print()

print(" Training complete!")
# Out:
#     Episode 200 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = HOLLY
#    ----------------------------------------
#    Turn 1: BIRKS
#    Turn 2: TANGO
#    Turn 3: LOVEY
#    Turn 4: WOLLY
#    Turn 5: FOLLY
#    Turn 6: MOLLY
#     FAILED
#
#     Game 2: Target = OVERT
#    ----------------------------------------
#    Turn 1: BIRKS
#    Turn 2: AWMRY
#    Turn 3: OUTRE
#    Turn 4: OVERT
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 93.0% | Avg Guesses: 0.10
#      Top First Guesses: [('birks', 98)]
#      Current Temperature: 1.45
#    Training: Temp=1.45
#
#     Episode 400 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CHAMP
#    ----------------------------------------
#    Turn 1: TAFFY
#    Turn 2: SHEAL
#    Turn 3: CHANK
#    Turn 4: CHARR
#    Turn 5: CHACO
#    Turn 6: CHAMP
#    SOLVED in 6 turns!
#
#     Game 2: Target = LOOSE
#    ----------------------------------------
#    Turn 1: TAFFY
#    Turn 2: BURRS
#    Turn 3: CISCO
#    Turn 4: SHMOE
#    Turn 5: GOOSE
#    Turn 6: LOOSE
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 84.0% | Avg Guesses: 0.12
#      Top First Guesses: [('taffy', 98)]
#      Current Temperature: 1.40
#    Training: Temp=1.40
#
#     Episode 600 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = WOOLY
#    ----------------------------------------
#    Turn 1: AWMRY
#    Turn 2: WICKY
#    Turn 3: WOLLY
#    Turn 4: WOOLY
#    SOLVED in 4 turns!
#
#     Game 2: Target = SWASH
#    ----------------------------------------
#    Turn 1: AWMRY
#    Turn 2: SWEAT
#    Turn 3: SWAGS
#    Turn 4: SWASH
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 91.0% | Avg Guesses: 0.08
#      Top First Guesses: [('awmry', 98)]
#      Current Temperature: 1.36
#    Training: Temp=1.36
#
#     Episode 800 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = STOOD
#    ----------------------------------------
#    Turn 1: AWMRY
#    Turn 2: DJINS
#    Turn 3: SHOED
#    Turn 4: SCOLD
#    Turn 5: STOOD
#    SOLVED in 5 turns!
#
#     Game 2: Target = WHALE
#    ----------------------------------------
#    Turn 1: AWMRY
#    Turn 2: WEAVE
#    Turn 3: WHALE
#    SOLVED in 3 turns!
#
#    Summary of 100 games:
#      Win Rate: 89.0% | Avg Guesses: 0.08
#      Top First Guesses: [('awmry', 98)]
#      Current Temperature: 1.31
#    Training: Temp=1.31
#
#     Episode 1000 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = FLUKE
#    ----------------------------------------
#    Turn 1: WEBER
#    Turn 2: PUNCE
#    Turn 3: AMUSE
#    Turn 4: VOUGE
#    Turn 5: FLUKE
#    SOLVED in 5 turns!
#
#     Game 2: Target = FORCE
#    ----------------------------------------
#    Turn 1: WEBER
#    Turn 2: FARSE
#    Turn 3: FORME
#    Turn 4: FORCE
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 92.0% | Avg Guesses: 0.09
#      Top First Guesses: [('weber', 94), ('cagot', 4)]
#      Current Temperature: 1.26
#    Training: Temp=1.26
#
#     Episode 1200 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = ARMOR
#    ----------------------------------------
#    Turn 1: RIVES
#    Turn 2: AWMRY
#    Turn 3: ARMOR
#    SOLVED in 3 turns!
#
#     Game 2: Target = PRINT
#    ----------------------------------------
#    Turn 1: RIVES
#    Turn 2: BRITT
#    Turn 3: DRIPT
#    Turn 4: PRINT
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 85.0% | Avg Guesses: 0.07
#      Top First Guesses: [('rives', 84), ('stays', 14)]
#      Current Temperature: 1.21
#    Training: Temp=1.21
#
#     Episode 1400 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = OPINE
#    ----------------------------------------
#    Turn 1: AMUSE
#    Turn 2: POKIE
#    Turn 3: OPINE
#    SOLVED in 3 turns!
#
#     Game 2: Target = DRAPE
#    ----------------------------------------
#    Turn 1: CAGOT
#    Turn 2: AMUSE
#    Turn 3: FLAKE
#    Turn 4: HEARE
#    Turn 5: IRADE
#    Turn 6: DRAPE
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 87.0% | Avg Guesses: 0.09
#      Top First Guesses: [('cagot', 70), ('amuse', 28)]
#      Current Temperature: 1.16
#    Training: Temp=1.16
#
#     Episode 1600 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = FERRY
#    ----------------------------------------
#    Turn 1: AMUSE
#    Turn 2: WEBER
#    Turn 3: REPRO
#    Turn 4: TERRY
#    Turn 5: JERRY
#    Turn 6: FERRY
#    SOLVED in 6 turns!
#
#     Game 2: Target = KARMA
#    ----------------------------------------
#    Turn 1: AMUSE
#    Turn 2: MACHI
#    Turn 3: KAAMA
#    Turn 4: KARMA
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 87.0% | Avg Guesses: 0.10
#      Top First Guesses: [('cagot', 70), ('amuse', 28)]
#      Current Temperature: 1.12
#    Training: Temp=1.12
#
#     Episode 1800 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = BLESS
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: COLDS
#    Turn 3: LYNES
#    Turn 4: BLEBS
#    Turn 5: BLETS
#    Turn 6: BLESS
#    SOLVED in 6 turns!
#
#     Game 2: Target = FORGO
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: DERED
#    Turn 3: GURLY
#    Turn 4: FORGO
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 87.0% | Avg Guesses: 0.10
#      Top First Guesses: [('sirra', 98)]
#      Current Temperature: 1.07
#    Training: Temp=1.07
#
#     Episode 2000 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CRICK
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: BRITT
#    Turn 3: PRIDE
#    Turn 4: GRILL
#    Turn 5: CRICK
#    SOLVED in 5 turns!
#
#     Game 2: Target = MOTTO
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: PUNCE
#    Turn 3: GODLY
#    Turn 4: BOMBO
#    Turn 5: MOTTO
#    SOLVED in 5 turns!
#
#    Summary of 100 games:
#      Win Rate: 85.0% | Avg Guesses: 0.10
#      Top First Guesses: [('sirra', 98)]
#      Current Temperature: 1.02
#    Training: Temp=1.02
#
#     Episode 2200 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CURIO
#    ----------------------------------------
#    Turn 1: DUDED
#    Turn 2: AURIS
#    Turn 3: CURIO
#    SOLVED in 3 turns!
#
#     Game 2: Target = HARPY
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: OMRAH
#    Turn 3: HARED
#    Turn 4: HARPY
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 85.0% | Avg Guesses: 0.07
#      Top First Guesses: [('duded', 54), ('sirra', 44)]
#      Current Temperature: 0.97
#    Training: Temp=0.97
#
#     Episode 2400 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = MIMIC
#    ----------------------------------------
#    Turn 1: ARISH
#    Turn 2: ZOOID
#    Turn 3: UNWIT
#    Turn 4: CYLIX
#    Turn 5: MIMIC
#    SOLVED in 5 turns!
#
#     Game 2: Target = CHICK
#    ----------------------------------------
#    Turn 1: ARISH
#    Turn 2: WHIPT
#    Turn 3: CHILL
#    Turn 4: CHIEF
#    Turn 5: CHING
#    Turn 6: CHICK
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 92.0% | Avg Guesses: 0.11
#      Top First Guesses: [('arish', 98)]
#      Current Temperature: 0.92
#    Training: Temp=0.92
#
#     Episode 2600 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = DEBAR
#    ----------------------------------------
#    Turn 1: THOLI
#    Turn 2: REWAN
#    Turn 3: SEGAR
#    Turn 4: CEDAR
#    Turn 5: DEBAR
#    SOLVED in 5 turns!
#
#     Game 2: Target = MIGHT
#    ----------------------------------------
#    Turn 1: THOLI
#    Turn 2: ITHER
#    Turn 3: HUTIA
#    Turn 4: FIGHT
#    Turn 5: NIGHT
#    Turn 6: MIGHT
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 88.0% | Avg Guesses: 0.11
#      Top First Guesses: [('tholi', 98)]
#      Current Temperature: 0.88
#    Training: Temp=0.88
#
#     Episode 2800 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = SHOAL
#    ----------------------------------------
#    Turn 1: BURRS
#    Turn 2: SHMOE
#    Turn 3: SHISO
#    Turn 4: SHOWD
#    Turn 5: SHOAL
#    SOLVED in 5 turns!
#
#     Game 2: Target = TITAN
#    ----------------------------------------
#    Turn 1: BURRS
#    Turn 2: LATKE
#    Turn 3: TITAN
#    SOLVED in 3 turns!
#
#    Summary of 100 games:
#      Win Rate: 91.0% | Avg Guesses: 0.08
#      Top First Guesses: [('burrs', 98)]
#      Current Temperature: 0.83
#    Training: Temp=0.83
#
#     Episode 3000 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CURSE
#    ----------------------------------------
#    Turn 1: BURRS
#    Turn 2: PURSE
#    Turn 3: NURSE
#    Turn 4: CURSE
#    SOLVED in 4 turns!
#
#     Game 2: Target = POINT
#    ----------------------------------------
#    Turn 1: BURRS
#    Turn 2: CAGOT
#    Turn 3: MOTET
#    Turn 4: DOILT
#    Turn 5: JOINT
#    Turn 6: POINT
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 92.0% | Avg Guesses: 0.10
#      Top First Guesses: [('burrs', 98)]
#      Current Temperature: 0.78
#    Training: Temp=0.78
#
#     Episode 3200 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = NUTTY
#    ----------------------------------------
#    Turn 1: LEMUR
#    Turn 2: SUNNA
#    Turn 3: NUTTY
#    SOLVED in 3 turns!
#
#     Game 2: Target = RADII
#    ----------------------------------------
#    Turn 1: LEMUR
#    Turn 2: ARISH
#    Turn 3: CAPRI
#    Turn 4: RANGI
#    Turn 5: RADII
#    SOLVED in 5 turns!
#
#    Summary of 100 games:
#      Win Rate: 89.0% | Avg Guesses: 0.08
#      Top First Guesses: [('lemur', 98)]
#      Current Temperature: 0.73
#    Training: Temp=0.73
#
#     Episode 3400 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = IGLOO
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: ULYIE
#    Turn 3: THOLI
#    Turn 4: INDOL
#    Turn 5: IGLOO
#    SOLVED in 5 turns!
#
#     Game 2: Target = RAISE
#    ----------------------------------------
#    Turn 1: SIRRA
#    Turn 2: ARISH
#    Turn 3: RAISE
#    SOLVED in 3 turns!
#
#    Summary of 100 games:
#      Win Rate: 89.0% | Avg Guesses: 0.08
#      Top First Guesses: [('sirra', 98)]
#      Current Temperature: 0.68
#    Training: Temp=0.68
#
#     Episode 3600 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = AFIRE
#    ----------------------------------------
#    Turn 1: CAGOT
#    Turn 2: ARISH
#    Turn 3: AFIRE
#    SOLVED in 3 turns!
#
#     Game 2: Target = BEFIT
#    ----------------------------------------
#    Turn 1: CAGOT
#    Turn 2: BRUNT
#    Turn 3: BLEST
#    Turn 4: BIDET
#    Turn 5: BEFIT
#    SOLVED in 5 turns!
#
#    Summary of 100 games:
#      Win Rate: 92.0% | Avg Guesses: 0.08
#      Top First Guesses: [('cagot', 98)]
#      Current Temperature: 0.64
#    Training: Temp=0.64
#
#     Episode 3800 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = PLUNK
#    ----------------------------------------
#    Turn 1: CESSE
#    Turn 2: GLAUR
#    Turn 3: BLUNK
#    Turn 4: FLUNK
#    Turn 5: PLUNK
#    SOLVED in 5 turns!
#
#     Game 2: Target = VIPER
#    ----------------------------------------
#    Turn 1: CESSE
#    Turn 2: GAYER
#    Turn 3: OUTER
#    Turn 4: BIKER
#    Turn 5: LIVER
#    Turn 6: VIPER
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 89.0% | Avg Guesses: 0.11
#      Top First Guesses: [('cesse', 86), ('sirra', 8), ('glaur', 4)]
#      Current Temperature: 0.59
#    Training: Temp=0.59
#
#     Episode 4000 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = FOIST
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: CESSE
#    Turn 3: WOOSH
#    Turn 4: FOIST
#    SOLVED in 4 turns!
#
#     Game 2: Target = DROIT
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: NITRE
#    Turn 3: DRIPT
#    Turn 4: DROIT
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 87.0% | Avg Guesses: 0.08
#      Top First Guesses: [('glaur', 98)]
#      Current Temperature: 0.54
#    Training: Temp=0.54
#
#     Episode 4200 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = DRYER
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: OTHER
#    Turn 3: BIKER
#    Turn 4: EMEER
#    Turn 5: DRYER
#    SOLVED in 5 turns!
#
#     Game 2: Target = DRONE
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: NITRE
#    Turn 3: RONDE
#    Turn 4: DRONE
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 87.0% | Avg Guesses: 0.09
#      Top First Guesses: [('glaur', 96), ('nitre', 2)]
#      Current Temperature: 0.49
#    Training: Temp=0.49
#
#     Episode 4400 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = LIVER
#    ----------------------------------------
#    Turn 1: NITRE
#    Turn 2: VIREO
#    Turn 3: RIVES
#    Turn 4: LIVER
#    SOLVED in 4 turns!
#
#     Game 2: Target = SPENT
#    ----------------------------------------
#    Turn 1: NITRE
#    Turn 2: TUNES
#    Turn 3: SCENT
#    Turn 4: SHENT
#    Turn 5: SPENT
#    SOLVED in 5 turns!
#
#    Summary of 100 games:
#      Win Rate: 92.0% | Avg Guesses: 0.09
#      Top First Guesses: [('nitre', 98)]
#      Current Temperature: 0.44
#    Training: Temp=0.44
#
#     Episode 4600 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CLOWN
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: CLIES
#    Turn 3: CLOMB
#    Turn 4: CLOOT
#    Turn 5: CLONK
#    Turn 6: CLOWN
#    SOLVED in 6 turns!
#
#     Game 2: Target = MUNCH
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: DOUBT
#    Turn 3: PUNCE
#    Turn 4: HUNCH
#    Turn 5: MUNCH
#    SOLVED in 5 turns!
#
#    Summary of 100 games:
#      Win Rate: 95.0% | Avg Guesses: 0.11
#      Top First Guesses: [('glaur', 97), ('nitre', 1)]
#      Current Temperature: 0.40
#    Training: Temp=0.40
#
#     Episode 4800 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = CABBY
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: TABIS
#    Turn 3: YABBY
#    Turn 4: CABBY
#    SOLVED in 4 turns!
#
#     Game 2: Target = FAITH
#    ----------------------------------------
#    Turn 1: GLAUR
#    Turn 2: TABIS
#    Turn 3: DAINT
#    Turn 4: WAITE
#    Turn 5: HAITH
#    Turn 6: FAITH
#    SOLVED in 6 turns!
#
#    Summary of 100 games:
#      Win Rate: 89.0% | Avg Guesses: 0.10
#      Top First Guesses: [('glaur', 98)]
#      Current Temperature: 0.35
#    Training: Temp=0.35
#
#     Episode 5000 - AGENT GUESSING PROCESS:
#    ==================================================
#
#     Game 1: Target = MISER
#    ----------------------------------------
#    Turn 1: BOETS
#    Turn 2: SPANE
#    Turn 3: WISED
#    Turn 4: EISEL
#    Turn 5: MISER
#    SOLVED in 5 turns!
#
#     Game 2: Target = ROTOR
#    ----------------------------------------
#    Turn 1: BOETS
#    Turn 2: COMPT
#    Turn 3: TONAL
#    Turn 4: ROTOR
#    SOLVED in 4 turns!
#
#    Summary of 100 games:
#      Win Rate: 93.0% | Avg Guesses: 0.09
#      Top First Guesses: [('boets', 98)]
#      Current Temperature: 0.30
#    Training: Temp=0.30
#
#  Training complete!

# %%
from google.colab import drive
drive.mount('/content/drive')
